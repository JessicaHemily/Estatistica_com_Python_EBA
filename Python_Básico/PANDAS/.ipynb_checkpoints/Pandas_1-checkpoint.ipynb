# %%
import pandas as pd

# %%
df = pd.read_csv("top10s.csv", encoding = 'latin1')
df
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.size
# Out:
# 9045

# %%
df.describe()
# Out:
#        Unnamed: 0         year         bpm        nrgy        dnce  \
# count  603.000000   603.000000  603.000000  603.000000  603.000000
# mean   302.000000  2014.592040  118.545605   70.504146   64.379768
# std    174.215384     2.607057   24.795358   16.310664   13.378718
# min      1.000000  2010.000000    0.000000    0.000000    0.000000
# 25%    151.500000  2013.000000  100.000000   61.000000   57.000000
# 50%    302.000000  2015.000000  120.000000   74.000000   66.000000
# 75%    452.500000  2017.000000  129.000000   82.000000   73.000000
# max    603.000000  2019.000000  206.000000   98.000000   97.000000
#
#                dB        live         val         dur       acous        spch  \
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean    -5.578773   17.774461   52.225539  224.674959   14.326700    8.358209
# std      2.798020   13.102543   22.513020   34.130059   20.766165    7.483162
# ...

# %%
df.isna()
# Out:
#      Unnamed: 0  title  artist  top genre   year    bpm   nrgy   dnce     dB  \
# 0         False  False   False      False  False  False  False  False  False
# 1         False  False   False      False  False  False  False  False  False
# 2         False  False   False      False  False  False  False  False  False
# 3         False  False   False      False  False  False  False  False  False
# 4         False  False   False      False  False  False  False  False  False
# ..          ...    ...     ...        ...    ...    ...    ...    ...    ...
# 598       False  False   False      False  False  False  False  False  False
# 599       False  False   False      False  False  False  False  False  False
# 600       False  False   False      False  False  False  False  False  False
# 601       False  False   False      False  False  False  False  False  False
# 602       False  False   False      False  False  False  False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# artist        0
# top genre     0
# year          0
# bpm           0
# nrgy          0
# dnce          0
# dB            0
# live          0
# val           0
# dur           0
# acous         0
# spch          0
# pop           0
# dtype: int64

# %%
df["artist"].unique()
# Out:
# array(['Train', 'Eminem', 'Kesha', 'Lady Gaga', 'Bruno Mars',
#        'Justin Bieber', 'Taio Cruz', 'OneRepublic', 'Alicia Keys',
#        'Rihanna', 'Flo Rida', 'Mike Posner', 'Far East Movement', 'Usher',
#        'Sean Kingston', 'The Black Eyed Peas', 'Adam Lambert', 'Maroon 5',
#        'Neon Trees', 'Selena Gomez & The Scene', 'Enrique Iglesias',
#        'Katy Perry', 'Britney Spears', '3OH!3', 'David Guetta',
#        'Christina Aguilera', 'Florence + The Machine', 'Shakira',
#        'Tinie Tempah', 'T.I.', 'Martin Solveig', 'Christina Perri',
#        'Adele', 'Pitbull', 'Beyoncé', 'Hot Chelle Rae', 'Avril Lavigne',
#        'Kanye West', 'LMFAO', 'Jessie J', 'Jennifer Lopez', 'Chris Brown',
#        'Sleeping At Last', 'Nicki Minaj', 'P!nk', 'Coldplay',
#        'One Direction', 'Taylor Swift', 'Carly Rae Jepsen',
#        'Kelly Clarkson', 'Owl City', 'The Wanted', 'fun.',
#        'Ellie Goulding', 'Gym Class Heroes', 'Avicii', 'The Script',
# ...

# %%
df["artist"].nunique()
# Out:
# 184

# %%
df.size
# Out:
# 9045

# %%
#As top 3 músicas com maior duração
df.nlargest(3,'dur')
# Out:
#      Unnamed: 0                                              title  \
# 188         189                                                TKO
# 422         423  Wish That You Were Here - From Miss Peregrine...
# 63           64                                            Monster
#
#                      artist    top genre  year  bpm  nrgy  dnce  dB  live  \
# 188       Justin Timberlake    dance pop  2013  138    68    61  -7    43
# 422  Florence + The Machine      art pop  2016   94    57    37  -6    13
# 63               Kanye West  chicago rap  2011  125    69    63  -6    67
#
#      val  dur  acous  spch  pop
# 188   49  424      1    24   58
# 422   12  403     72     3   57
# 63    10  379      0    20   73

# %%
#As top 3 músicas com menor duração
df.nsmallest(3,'dur')
# Out:
#      Unnamed: 0                            title         artist     top genre  \
# 330         331                    Mark My Words  Justin Bieber  canadian pop
# 591         592  All Around The World (La La La)          R3HAB      big room
# 174         175     I Love It (feat. Charli XCX)      Icona Pop     candy pop
#
#      year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 330  2015  114    26    38  -9    17   52  134     88     3   63
# 591  2019  125    86    73  -5    11   52  148     48     3   82
# 174  2013  126    91    71  -3    15   82  157      1     3   67

# %%
df2 = df.drop_duplicates("title")
df2
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
df2.fillna(0)
df2
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
#Matriz transposta
df2.T
# Out:
#                          0                     1          2            3    \
# Unnamed: 0                 1                     2          3            4
# title       Hey, Soul Sister  Love The Way You Lie    TiK ToK  Bad Romance
# artist                 Train                Eminem      Kesha    Lady Gaga
# top genre         neo mellow       detroit hip hop  dance pop    dance pop
# year                    2010                  2010       2010         2010
# bpm                       97                    87        120          119
# nrgy                      89                    93         84           92
# dnce                      67                    75         76           70
# dB                        -4                    -5         -3           -4
# live                       8                    52         29            8
# val                       80                    64         71           71
# ...

# %%
#Seleciona amostra aleatória
df2.sample(5)
# Out:
#      Unnamed: 0                               title        artist  \
# 539         540                            Bad Liar  Selena Gomez
# 435         436  One Call Away (feat. Tyga) - Remix  Charlie Puth
# 257         258                            Anaconda   Nicki Minaj
# 37           38                        If I Had You  Adam Lambert
# 371         372                           Needed Me       Rihanna
#
#           top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 539       dance pop  2018  121    41    97  -6     8   73  215     19     7
# 435       dance pop  2016   91    69    75  -5    13   52  192     26     4
# 257       dance pop  2014  130    60    96  -6    21   65  260      7    18
# 37   australian pop  2010  131    91    65  -4    37   79  228      1    11
# 371   barbadian pop  2016  111    31    67  -8     8   30  192     11    24
#
#      pop
# 539   75
# 435   41
# 257   50
# 37    59
# 371   80

# %%
#Músicas da Ariana Grande
df[df["artist"]=='Ariana Grande']
# Out:
#      Unnamed: 0                 title         artist  top genre  year  bpm  \
# 171         172               The Way  Ariana Grande  dance pop  2013   82
# 221         222               Problem  Ariana Grande  dance pop  2014  103
# 287         288        Love Me Harder  Ariana Grande  dance pop  2015   99
# 291         292            Break Free  Ariana Grande  dance pop  2015  130
# 323         324                 Focus  Ariana Grande  dance pop  2015  100
# 368         369              Into You  Ariana Grande  dance pop  2016  108
# 381         382       Dangerous Woman  Ariana Grande  dance pop  2016  134
# 451         452          Side To Side  Ariana Grande  dance pop  2017  159
# 513         514  no tears left to cry  Ariana Grande  dance pop  2018  122
#
#      nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 171    88    65  -3     8   86  227     29    11   68
# 221    81    66  -5    16   63  194      2    15   75
# 287    71    47  -4     8   24  236      1     3   76
# ...

# %%
#Número de músicas da Ariana Grande
df[df["artist"]=='Ariana Grande']["artist"].count()
# Out:
# 9

# %%
(df[df["artist"]=='Ariana Grande'])[['title','year']]
# Out:
#                     title  year
# 171               The Way  2013
# 221               Problem  2014
# 287        Love Me Harder  2015
# 291            Break Free  2015
# 323                 Focus  2015
# 368              Into You  2016
# 381       Dangerous Woman  2016
# 451          Side To Side  2017
# 513  no tears left to cry  2018

# %%
df[df['dur']>200]
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# 5             6                                               Baby
# ..          ...                                                ...
# 596         597    Taki Taki (feat. Selena Gomez, Ozuna & Cardi B)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
#Seleciona a coluna de forma ascendente
df["dur"].sort_values()
# Out:
# 330    134
# 591    148
# 174    157
# 492    158
# 581    159
#       ...
# 194    353
# 162    354
# 63     379
# 422    403
# 188    424
# Name: dur, Length: 603, dtype: int64

# %%
#Retorna do df, de modo que a ordem da coluna "dur" seja ascendente
df2.sort_values(by = 'dur')
# Out:
#      Unnamed: 0                                              title  \
# 330         331                                      Mark My Words
# 591         592                    All Around The World (La La La)
# 174         175                       I Love It (feat. Charli XCX)
# 492         493          Reality (feat. Janieck Devy) - Radio Edit
# 581         582         Good as Hell (feat. Ariana Grande) - Remix
# ..          ...                                                ...
# 194         195                                Take Back the Night
# 162         163                             Lose Yourself to Dance
# 63           64                                            Monster
# 422         423  Wish That You Were Here - From Miss Peregrine...
# 188         189                                                TKO
#
#                      artist     top genre  year  bpm  nrgy  dnce  dB  live  \
# 330           Justin Bieber  canadian pop  2015  114    26    38  -9    17
# ...

# %%
#Ordena do maior para o menor
df2.sort_values(by='dur',ascending=False)
# Out:
#      Unnamed: 0                                              title  \
# 188         189                                                TKO
# 422         423  Wish That You Were Here - From Miss Peregrine...
# 63           64                                            Monster
# 162         163                             Lose Yourself to Dance
# 194         195                                Take Back the Night
# ..          ...                                                ...
# 334         335                               Reality - Radio Edit
# 492         493          Reality (feat. Janieck Devy) - Radio Edit
# 174         175                       I Love It (feat. Charli XCX)
# 591         592                    All Around The World (La La La)
# 330         331                                      Mark My Words
#
#                      artist     top genre  year  bpm  nrgy  dnce  dB  live  \
# 188       Justin Timberlake     dance pop  2013  138    68    61  -7    43
# ...

# %%
#Ordena do menor para o maior
# ascending = True é PADRÃO
# df2.sort_values(by='dur',ascending=True) == df2.sort_values(by='dur')
df2.sort_values(by='dur',ascending=True)
# Out:
#      Unnamed: 0                                              title  \
# 330         331                                      Mark My Words
# 591         592                    All Around The World (La La La)
# 174         175                       I Love It (feat. Charli XCX)
# 492         493          Reality (feat. Janieck Devy) - Radio Edit
# 581         582         Good as Hell (feat. Ariana Grande) - Remix
# ..          ...                                                ...
# 194         195                                Take Back the Night
# 162         163                             Lose Yourself to Dance
# 63           64                                            Monster
# 422         423  Wish That You Were Here - From Miss Peregrine...
# 188         189                                                TKO
#
#                      artist     top genre  year  bpm  nrgy  dnce  dB  live  \
# 330           Justin Bieber  canadian pop  2015  114    26    38  -9    17
# ...

# %%
(df2["artist"]=="Madonna").any()
# Out:
# True

# %%
df2.groupby('artist')['title'].count()
# Out:
# artist
# 3OH!3                  1
# 5 Seconds of Summer    1
# A Great Big World      1
# Adam Lambert           2
# Adele                  8
#                       ..
# ZAYN                   5
# Zara Larsson           1
# Zedd                   6
# fun.                   2
# will.i.am              1
# Name: title, Length: 184, dtype: int64

# %%
df_teste = df2.groupby('artist')['title'].count()
df_teste = df_teste.reset_index()
df_teste = df_teste.rename(columns = {'title':'contagem_de_title'})
df_teste = df_teste.sort_values(by='contagem_de_title', ascending = False)
df_teste
# Out:
#             artist  contagem_de_title
# 86      Katy Perry                 17
# 145        Rihanna                 15
# 83   Justin Bieber                 14
# 114       Maroon 5                 14
# 94       Lady Gaga                 14
# ..             ...                ...
# 85      Kanye West                  1
# 81      Jonas Blue                  1
# 80     John Newman                  1
# 78    Joey Montana                  1
# 183      will.i.am                  1
#
# [184 rows x 2 columns]

# %%
df_contagem_musicas = df2.groupby(['artist','year'])['title'].count()
df_contagem_musicas = df_contagem_musicas.reset_index()
df_contagem_musicas = df_contagem_musicas.rename(columns = {'title':'contagem_title'})
df_contagem_musicas = df_contagem_musicas.sort_values(by='contagem_title', ascending=False)
df_contagem_musicas
# Out:
#                 artist  year  contagem_title
# 185      Justin Bieber  2015               9
# 116         Ed Sheeran  2019               5
# 214          Lady Gaga  2011               5
# 187  Justin Timberlake  2013               4
# 350       Shawn Mendes  2018               4
# ..                 ...   ...             ...
# 147   Hailee Steinfeld  2016               1
# 146   Gym Class Heroes  2012               1
# 145       Gwen Stefani  2016               1
# 143           Galantis  2017               1
# 398          will.i.am  2013               1
#
# [399 rows x 3 columns]

# %%
df2.groupby(['artist','year'])[['bpm','dur']].mean()
# Out:
#                             bpm    dur
# artist              year
# 3OH!3               2010  138.0  192.0
# 5 Seconds of Summer 2014  160.0  202.0
# A Great Big World   2014  138.0  229.0
# Adam Lambert        2010  158.5  227.5
# Adele               2011  120.0  256.5
# ...                         ...    ...
# Zedd                2015  130.0  240.0
#                     2016  126.0  225.0
#                     2017  105.0  207.5
# fun.                2012  146.0  264.0
# will.i.am           2013  128.0  280.0
#
# [399 rows x 2 columns]

# %%
df2.groupby(['artist','year']).agg({'dur':'mean','year':'count'})
# Out:
#                             dur  year
# artist              year
# 3OH!3               2010  192.0     1
# 5 Seconds of Summer 2014  202.0     1
# A Great Big World   2014  229.0     1
# Adam Lambert        2010  227.5     2
# Adele               2011  256.5     2
# ...                         ...   ...
# Zedd                2015  240.0     1
#                     2016  225.0     1
#                     2017  207.5     2
# fun.                2012  264.0     2
# will.i.am           2013  280.0     1
#
# [399 rows x 2 columns]

# %%
lista = ['chocolate','caramelo','bala']

# %%
type(lista)
# Out:
# list

# %%
tupla = ('chocolate','caramelo')
type(tupla)
# Out:
# tuple

# %%
conjunto = {'chocolate','caramelo','marshmallow'}
type(conjunto)
# Out:
# set

# %%
dicionario = {'doce':['chocolate','marshmallow'],'salgado':['kibe','pastel']}
dicionario
# Out:
# {'doce': ['chocolate', 'marshmallow'], 'salgado': ['kibe', 'pastel']}

# %%
type(dicionario)
# Out:
# dict

# %%
dff = pd.DataFrame(dicionario)
dff
# Out:
#           doce salgado
# 0    chocolate    kibe
# 1  marshmallow  pastel
